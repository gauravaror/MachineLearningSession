# %% [markdown]
# # Create a dictionary from text sentences
#
# ## Given/ Define list of sentences "Machine learning workshop in University", "university is also hosting a symposium", "students get to learn a lot from symposium"

# %%
# Download package in nltk for word tokenization
import nltk
#nltk.download('punkt')
#nltk.download('stopwords')

# %%
from nltk import sent_tokenize, word_tokenize, pos_tag
texts = ["Machine learning workshop in University", 
         "university is also hosting a symposium", 
         "students get to learn a lot from symposium",
          "learning is a continous process",
          "university is located in central part of city"]

print("Texts : ", texts)
tokens = [ word_tokenize(text.lower()) for text in texts]
print("Tokens : " , tokens)

dictionary = {}

for token_list in tokens: 
    for token in token_list:
        if token in dictionary:
            dictionary[token] += 1
        else:
            dictionary[token] = 1
print("Dictionary", dictionary)
# Out:
# Texts :  ['Machine learning workshop in University', 'university is also hosting a symposium', 'students get to learn a lot from symposium', 'learning is a continous process', 'university is located in central part of city']
# Tokens :  [['machine', 'learning', 'workshop', 'in', 'university'], ['university', 'is', 'also', 'hosting', 'a', 'symposium'], ['students', 'get', 'to', 'learn', 'a', 'lot', 'from', 'symposium'], ['learning', 'is', 'a', 'continous', 'process'], ['university', 'is', 'located', 'in', 'central', 'part', 'of', 'city']]
# Dictionary {'also': 1, 'get': 1, 'workshop': 1, 'located': 1, 'university': 3, 'is': 3, 'in': 2, 'continous': 1, 'of': 1, 'process': 1, 'symposium': 2, 'to': 1, 'hosting': 1, 'city': 1, 'learning': 2, 'part': 1, 'learn': 1, 'from': 1, 'machine': 1, 'lot': 1, 'a': 3, 'central': 1, 'students': 1}

# %% [markdown]
# ## Let's filter out all the terms with frequency less than or equal to  1

# %%
filtered_dictionary = {key: value for key, value in dictionary.items() if value >1}
print(filtered_dictionary)
# Out:
# {'a': 3, 'learning': 2, 'symposium': 2, 'in': 2, 'university': 3, 'is': 3}

# %% [markdown]
# # Let's remove stop words like in, a, is

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
 
example_sent = "This is a sample sentence, showing off the stop words filtration."
 
stop_words = set(stopwords.words('english'))
 
word_tokens = word_tokenize(example_sent)
 
filtered_sentence = [w for w in word_tokens if not w in stop_words]
 
filtered_sentence = []
 
for w in word_tokens:
    if w not in stop_words:
        filtered_sentence.append(w)
 
print(word_tokens)
print(filtered_sentence)
# Out:
# ['This', 'is', 'a', 'sample', 'sentence', ',', 'showing', 'off', 'the', 'stop', 'words', 'filtration', '.']
# ['This', 'sample', 'sentence', ',', 'showing', 'stop', 'words', 'filtration', '.']

# %% [markdown]
# # Sentiment Analysis

# %%
## Download data
nltk.download('movie_reviews')

# %%
import nltk.classify.util
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import movie_reviews
 
def word_feats(words):
    return dict([(word, True) for word in words])
 
negids = movie_reviews.fileids('neg')
posids = movie_reviews.fileids('pos')
 
#print(negids)
print(movie_reviews.words(fileids='neg/cv000_29416.txt'))
negfeats = [(word_feats(movie_reviews.words(fileids=[f])), 'neg') for f in negids]
posfeats = [(word_feats(movie_reviews.words(fileids=[f])), 'pos') for f in posids]
print(negfeats[1:100])
negcutoff = int(len(negfeats)*3/4)
poscutoff = int(len(posfeats)*3/4)
print("Negative cutoff  : ", negcutoff , " Positive cutoff : " , poscutoff)
trainfeats = negfeats[:negcutoff] + posfeats[:poscutoff]
testfeats = negfeats[negcutoff:] + posfeats[poscutoff:]
print('train on', len(trainfeats),' instances, test on' , len(testfeats)  , ' instances')
 
classifier = NaiveBayesClassifier.train(trainfeats)
print('accuracy:', nltk.classify.util.accuracy(classifier, testfeats))
classifier.show_most_informative_features()
# Out:
# ['plot', ':', 'two', 'teen', 'couples', 'go', 'to', ...]
# ...
